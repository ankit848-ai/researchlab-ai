# %% [markdown]
# # ResearchLab-AI Demo Notebook
#
# This notebook runs the full pipeline:
# 1. Researcher Agent
# 2. Designer Agent
# 3. Coder + Executor Agent
# 4. Analyst Agent
# 5. Writer Agent

# %%
from agents.orchestrator import Orchestrator

orch = Orchestrator()

print('Running ResearchLab-AI Pipeline...')

topic = "sentiment analysis experiment"
results = orch.run(topic, mode="demo")

results

# %% [markdown]
# ## ✔ Artifacts Generated
# - research paper PDF
# - slide deck PPTX
# - accuracy plot
# - metrics JSON
# - execution logs
